# %% [markdown]
# <a href="https://colab.research.google.com/github/jagjeetkaur123/aws-codepipeline-s3-codedeploy-linux/blob/master/DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg"
# Out:
# --2023-03-02 03:50:25--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 54.230.18.61, 54.230.18.111, 54.230.18.103, ...
# Connecting to tractive.com (tractive.com)|54.230.18.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg.8’
#
# puppy-care-guide-fo 100%[===================>] 110.91K  --.-KB/s    in 0.02s
#
# 2023-03-02 03:50:25 (4.66 MB/s) - ‘puppy-care-guide-for-new-parents.jpg.8’ saved [113570/113570]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/puppy-care-guide-for-new-parents.jpg')

# %%
type(img)
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
print(img)
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/puppy-care-guide-for-new-parents.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img = mpimg.imread('/content/dog_image_resized.jpg')
img_plot = plt.imshow(img)
plt.show()

# %%
print(img.shape)
# Out:
# (200, 200, 3)

# %%
# converting RGB images to Grayscale Image
import cv2
img = cv2.imread('/content/dog_image_resized.jpg')

# %%
# how to change color photo to grayscale

type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
#grayscale
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (200, 200)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7FBD62A49880>
